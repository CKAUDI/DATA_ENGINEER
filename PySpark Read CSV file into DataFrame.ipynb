# %%
#PySpark Read CSV file into DataFrame
# Import
from pyspark.sql import SparkSession

# Create SparkSession
spark = SparkSession.builder.appName("SparkByExamples.om").getOrCreate()

# Read CSV File
df = spark.read.csv("/Workspace/Users/chiru.adf@gmail.com/DATA_ENGINEER/Files/Player.csv")
df.printSchema()
df.show()

#Writing PySpark DataFrame to CSV file


df.write.option("header",True) \
 .csv("/Workspace/Users/chiru.adf@gmail.com/DATA_ENGINEER/Files/zipcode")

# %%
## Using format().load()
df = spark.read.format("csv").load("/Workspace/Users/chiru.adf@gmail.com/DATA_ENGINEER/Files/Player.csv")
df.printSchema()

#or

df= spark.read.format("com.databricks.spark.csv").load("/Workspace/Users/chiru.adf@gmail.com/DATA_ENGINEER/Files/Player.csv")
df.printSchema()

# %%
#1.1 Using Header Record For Column Names

df2 = spark.read.option("header", True).csv("/Workspace/Users/chiru.adf@gmail.com/DATA_ENGINEER/Files/Player.csv")
df2.printSchema()

# %%
#Reading Mulitple CSV Files

df3 = spark.read.csv([
    "/Workspace/Users/chiru.adf@gmail.com/DATA_ENGINEER/Files/Player.csv",
    "/Workspace/Users/chiru.adf@gmail.com/DATA_ENGINEER/Files/Player.csv"
])
df3.printSchema()

# %%
#Reading CSV File Options

# Syntax
# option(self, key, value) # Using single options
# options(self, **options) # Using multiple options
#2.1 delimiter

df3 = spark.read.option("delimiter" ,",").csv("/Workspace/Users/chiru.adf@gmail.com/DATA_ENGINEER/Files/Player.csv").printSchema()

# %%
#2.2 inferSchema

df4 = spark.read.options(inferSchema="True", delimiter =",").csv("/Workspace/Users/chiru.adf@gmail.com/DATA_ENGINEER/Files/Player.csv").printSchema()

options = {
    "inferSchema" : "True",
    "delimiter" : ","
}

df5 = spark.read.options(**options).csv("/Workspace/Users/chiru.adf@gmail.com/DATA_ENGINEER/Files/Player.csv").printSchema()

# Chaining multiple options
df6 = spark.read.option("inferSchema",True) \
                .option("delimiter",",") \
  .csv("/path/zipcodes.csv")

# %%
df7 = spark.read.options(inferSchema = 'True',header = 'True', delimiter = ',').csv("/Workspace/Users/chiru.adf@gmail.com/DATA_ENGINEER/Files/Player.csv").printSchema()

# %%
 
# Imports
from pyspark.sql.types import StructType,StructField, StringType, IntegerType 
from pyspark.sql.types import ArrayType, DoubleType, BooleanType

# Using custom schema
schema = StructType() \
      .add("RecordNumber",IntegerType(),True) \
      .add("Zipcode",IntegerType(),True) \
      .add("ZipCodeType",StringType(),True) \
      .add("City",StringType(),True) \
      .add("State",StringType(),True) \
      .add("LocationType",StringType(),True) \
      .add("Lat",DoubleType(),True) \
      .add("Long",DoubleType(),True) \
      .add("Xaxis",IntegerType(),True) \
      .add("Yaxis",DoubleType(),True) \
      .add("Zaxis",DoubleType(),True) \
      .add("WorldRegion",StringType(),True) \
      .add("Country",StringType(),True) \
      .add("LocationText",StringType(),True) \
      .add("Location",StringType(),True) \
      .add("Decommisioned",BooleanType(),True) \
      .add("TaxReturnsFiled",StringType(),True) \
      .add("EstimatedPopulation",IntegerType(),True) \
      .add("TotalWages",IntegerType(),True) \
      .add("Notes",StringType(),True)
      
df_with_schema = spark.read.format("csv") \
      .option("header", True) \
      .schema(schema) \
      .load("/Workspace/Users/chiru.adf@gmail.com/DATA_ENGINEER/Files/Player.csv")

# %%
#Writing PySpark DataFrame to CSV file  using write.csv()

df.write.mode("overwrite").csv(
    "dbfs:/Users/chiru.adf@gmail.com/zipcodes_output"
)

# %%
 
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType,StructField, StringType, IntegerType 
from pyspark.sql.types import ArrayType, DoubleType, BooleanType
from pyspark.sql.functions import col,array_contains

spark = SparkSession.builder.appName('SparkByExamples.com').getOrCreate()

df = spark.read.csv("/tmp/resources/zipcodes.csv")

df.printSchema()

df2 = spark.read.option("header",True) \
     .csv("/tmp/resources/zipcodes.csv")
df2.printSchema()
   
df3 = spark.read.options(header='True', delimiter=',') \
  .csv("/tmp/resources/zipcodes.csv")
df3.printSchema()

schema = StructType() \
      .add("RecordNumber",IntegerType(),True) \
      .add("Zipcode",IntegerType(),True) \
      .add("ZipCodeType",StringType(),True) \
      .add("City",StringType(),True) \
      .add("State",StringType(),True) \
      .add("LocationType",StringType(),True) \
      .add("Lat",DoubleType(),True) \
      .add("Long",DoubleType(),True) \
      .add("Xaxis",IntegerType(),True) \
      .add("Yaxis",DoubleType(),True) \
      .add("Zaxis",DoubleType(),True) \
      .add("WorldRegion",StringType(),True) \
      .add("Country",StringType(),True) \
      .add("LocationText",StringType(),True) \
      .add("Location",StringType(),True) \
      .add("Decommisioned",BooleanType(),True) \
      .add("TaxReturnsFiled",StringType(),True) \
      .add("EstimatedPopulation",IntegerType(),True) \
      .add("TotalWages",IntegerType(),True) \
      .add("Notes",StringType(),True)
      
df_with_schema = spark.read.format("csv") \
      .option("header", True) \
      .schema(schema) \
      .load(/tmp/resources/zipcodes.csv")
df_with_schema.printSchema()

df2.write.option("header",True) \
 .csv("/tmp/spark_output/zipcodes123")
